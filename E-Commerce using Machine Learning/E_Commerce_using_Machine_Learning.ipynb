# %% [markdown]
# <a href="https://colab.research.google.com/github/davinavc/Data-Analyst/blob/main/E-Commerce%20using%20Machine%20Learning/E_Commerce_using_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Seting: matplotlib and seaborn
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')

# %%
# Read data 'ecommerce_banner_promo.csv'
data = pd.read_csv('https://storage.googleapis.com/dqlab-dataset/pythonTutorial/ecommerce_banner_promo.csv')

# %%
#1. Data explore using head(), info(), describe(), shape
print("\n[1] Data eksplorasi dengan head(), info(), describe(), shape")
print("Top 5 data:")
print(data.head())
print("Dataset information:")
print(data.info())
print("Dataset statistic descriptive:")
print(data.describe())
print("Dataset size:")
print(data.shape)

# %%
#2. Exploratory data analysis by checking the correlation of each feature using the corr() function
print("\n[2] Exploratory data analysis by checking the correlation of each feature using the corr() function")
print(data.corr())

# %%
#3. Exploratory data analysis by checking the distribution of labels using the groupby() and size() functions
print("\n[3] Exploratory data analysis by checking the distribution of labels using the groupby() and size() functions")
print(data.groupby(['Clicked on Ad']).size())

# %%
#4. Data eksplorasi dengan visualisasi
#4a. Visualisasi Jumlah user dibagi ke dalam rentang usia (Age) menggunakan histogram (hist()) plot
plt.figure(figsize=(10, 5))
plt.hist(data['Age'], bins = data.Age.nunique())
plt.xlabel('Jumlah user dibagi ke dalam rentang usia (Age)')
plt.tight_layout()
plt.show()

# %%
#4b. Gunakan pairplot() dari seaborn (sns) modul untuk menggambarkan hubungan setiap feature.
plt.figure()
sns.pairplot(data)
plt.show()
